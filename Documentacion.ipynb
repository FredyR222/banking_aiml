# %% [markdown]
# **Por:** Fredy Alexi Romero Perez. **email:** fredyperez145@gmail.com
# **Proyecto de Predicción de Marketing Bancario**
#
# -La fuente de datos se obtuvo por kaggle [https://www.kaggle.com/datasets/rouseguy/bankbalanced] el cual tomo una muestra equilibrada del origen de datos que es [https://archive.ics.uci.edu/dataset/222/bank+marketing]
#
# -En el origen de los datos nos brinda la descripcion de cada columna
# # bank client data:
#    1 - age (numeric)
#    2 - job : type of job (categorical: "admin.","unknown","unemployed","management","housemaid","entrepreneur","student",
#                                        "blue-collar","self-employed","retired","technician","services")
#    3 - marital : marital status (categorical: "married","divorced","single"; note: "divorced" means divorced or widowed)
#    4 - education (categorical: "unknown","secondary","primary","tertiary")
#    5 - default: has credit in default? (binary: "yes","no")
#    6 - balance: average yearly balance, in euros (numeric)
#    7 - housing: has housing loan? (binary: "yes","no")
#    8 - loan: has personal loan? (binary: "yes","no")
#    # related with the last contact of the current campaign:
#    9 - contact: contact communication type (categorical: "unknown","telephone","cellular")
#   10 - day: last contact day of the month (numeric)
#   11 - month: last contact month of year (categorical: "jan", "feb", "mar", ..., "nov", "dec")
#   12 - duration: last contact duration, in seconds (numeric)
#    # other attributes:
#   13 - campaign: number of contacts performed during this campaign and for this client (numeric, includes last contact)
#   14 - pdays: number of days that passed by after the client was last contacted from a previous campaign (numeric, -1 means client was not previously contacted)
#   15 - previous: number of contacts performed before this campaign and for this client (numeric)
#   16 - poutcome: outcome of the previous marketing campaign (categorical: "unknown","other","failure","success")
#
#   Output variable (desired target):
#   17 - y - has the client subscribed a term deposit? (binary: "yes","no")
#
#   **Nota: el valor 'y' fue tomado con el nombre 'deposit' brindado en el dataset de kaggle**
#
#   [Proceso]
#   - Se realizó el cambio de tipo de variables para las columnas en la que es necesario
#   - A los valores de `deposit` se cambió de yes y no a valores boleanos: 1=yes y 0=no
#   - Se realizaron dos entrenamientos de DecisionTreeClassifier:
#         - Usando los valores sin eliminación de los Outliers:
#             | Predicción: 0 | Predicción: 1 |
#             | ----------- | ------------- | ------------- |
#             | **Real: 0** | 1465 (TN)     | 297 (FP)      |
#             | **Real: 1** | 462 (FN)      | 1125 (TP)     |
#             **Con un accuracy de:** 0.77 -->77%
#             **F1 promedio:** 0.7149074766072671
#             **Precisión promedio:** 0.752733183187725
#             Al usar el KFold de 5 se obtuvo un promedio de aprox 0.7904
#             [0.78952082, 0.79579042, 0.80062724, 0.77464158, 0.79166667]
#         - Usando los valores con eliminación de los Outliers
#           en ['age', 'balance', 'campaign', 'previous', 'deposit']:
#             | Predicción: 0 | Predicción: 1 |
#             | ----------- | ------------- | ------------- |
#             | **Real: 0** | 1158 (TN)     | 232 (FP)      |
#             | **Real: 1** | 342 (FN)      | 771 (TP)     |
#             **Con un accuracy de:** 0.77 -->77%
#             **F1 promedio:** 0.7126386549687489
#             **Precisión promedio:** 0.7492148894552294
#             Al usar el KFold de 5 se obtuvo un promedio de aprox 0.7999
#             [0.80347513, 0.78849611, 0.79868185, 0.80995204, 0.79916067]
#     - Los datos fueron balanceados en el segmento de entrenamiento
#
# Se obtienen resultados muy parecidos, donde se tiene que evaluar si el porcentaje de accuracy es lo suficientemente alto, intentar mejorarlo por medio de las métricas utilizadas
